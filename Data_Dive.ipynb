# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishverma5218/Hackathon_Deep_Dive_Project/blob/main/Data_Dive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Hackathon - Data Dive
# #Collage - JNCT Collage
# #Team - Tech Army(Ashish Verma, Pawan Sondhiya, Ajeet Pal)

# %% [markdown]
# ## Import Statements

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# **Challenge**: Read the .csv file and store it in a Pandas dataframe

# %%
df = pd.read_csv("/content/drive/MyDrive/QueryResults (1).csv")
df
# Out:
#                         m   TagName  Unnamed: 2
# 0     2008-07-01 00:00:00        c#           3
# 1     2008-08-01 00:00:00  assembly           8
# 2     2008-08-01 00:00:00         c          83
# 3     2008-08-01 00:00:00        c#         505
# 4     2008-08-01 00:00:00       c++         164
# ...                   ...       ...         ...
# 2421  2023-02-01 00:00:00       php        3144
# 2422  2023-02-01 00:00:00    python       18291
# 2423  2023-02-01 00:00:00         r        4001
# 2424  2023-02-01 00:00:00      ruby         353
# 2425  2023-02-01 00:00:00     swift        1528
#
# [2426 rows x 3 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# DO NOT CODE HERE
# Out:
#                         m   TagName  Unnamed: 2
# 0     2008-07-01 00:00:00        c#           3
# 1     2008-08-01 00:00:00  assembly           8
# 2     2008-08-01 00:00:00         c          83
# 3     2008-08-01 00:00:00        c#         505
# 4     2008-08-01 00:00:00       c++         164
# ...                   ...       ...         ...
# 2421  2023-02-01 00:00:00       php        3144
# 2422  2023-02-01 00:00:00    python       18291
# 2423  2023-02-01 00:00:00         r        4001
# 2424  2023-02-01 00:00:00      ruby         353
# 2425  2023-02-01 00:00:00     swift        1528
#
# [2426 rows x 3 columns]

# %% [markdown]
# **Challenge**: Examine the first 5 rows and the last 5 rows of the of the dataframe<br>
# And change column name to "DATE", "TAG", "POSTS"

# %%
df.rename(columns={'m': 'DATE', 'TagName': 'TAG','Unnamed: 2': 'POSTS'}, inplace=True)
df.head()
# Out:
#                   DATE       TAG  POSTS
# 0  2008-07-01 00:00:00        c#      3
# 1  2008-08-01 00:00:00  assembly      8
# 2  2008-08-01 00:00:00         c     83
# 3  2008-08-01 00:00:00        c#    505
# 4  2008-08-01 00:00:00       c++    164

# %%
# DO NOT CODE HERE
# Out:
#                   DATE       TAG  POSTS
# 0  2008-07-01 00:00:00        c#      3
# 1  2008-08-01 00:00:00  assembly      8
# 2  2008-08-01 00:00:00         c     83
# 3  2008-08-01 00:00:00        c#    505
# 4  2008-08-01 00:00:00       c++    164

# %% [markdown]
# **Challenge:** Check how many rows and how many columns there are.
# What are the dimensions of the dataframe?

# %%
df.shape
# Out:
# (2426, 3)

# %%
# DO NOT CODE HERE
# Out:
# (2426, 3)

# %% [markdown]
# **Challenge**: Count the number of entries in each column of the dataframe

# %%
df.count()
# Out:
# DATE     2426
# TAG      2426
# POSTS    2426
# dtype: int64

# %%
# DO NOT CODE HERE
# Out:
# DATE     2426
# TAG      2426
# POSTS    2426
# dtype: int64

# %% [markdown]
# **Challenge**: Calculate the total number of post per language.
# Which Programming language has had the highest total number of posts of all time?

# %%
df.groupby('TAG').sum()
# Out:
# <ipython-input-9-e0b10c91de87>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('TAG').sum()
#               POSTS
# TAG
# assembly      42330
# c            393627
# c#          1582934
# c++          789219
# delphi        50605
# go            67841
# java        1888656
# javascript  2477923
# perl          67525
# php         1455671
# python      2110033
# r            482600
# ruby         227425
# swift        324984

# %%
# DO NOT CODE HERE
# Out:
#               POSTS
# TAG
# assembly      42330
# c            393627
# c#          1582934
# c++          789219
# delphi        50605
# go            67841
# java        1888656
# javascript  2477923
# perl          67525
# php         1455671
# python      2110033
# r            482600
# ruby         227425
# swift        324984

# %% [markdown]
# Some languages are older (e.g., C) and other languages are newer (e.g., Swift). The dataset starts in September 2008.
#
# **Challenge**: How many months of data exist per language? Which language had the fewest months with an entry?

# %%
df.groupby('TAG').count()
# Out:
#             DATE  POSTS
# TAG
# assembly     175    175
# c            175    175
# c#           176    176
# c++          175    175
# delphi       175    175
# go           160    160
# java         175    175
# javascript   175    175
# perl         175    175
# php          175    175
# python       175    175
# r            173    173
# ruby         175    175
# swift        167    167

# %%
# DO NOT CODE HERE
# Out:
#             DATE  POSTS
# TAG
# assembly     175    175
# c            175    175
# c#           176    176
# c++          175    175
# delphi       175    175
# go           160    160
# java         175    175
# javascript   175    175
# perl         175    175
# php          175    175
# python       175    175
# r            173    173
# ruby         175    175
# swift        167    167

# %% [markdown]
# ## Data Cleaning
#
# Let's fix the date format to make it more readable. We need to use Pandas to change format from a string of "2008-07-01 00:00:00" to a datetime object with the format of "2008-07-01"

# %%
# CHANGE THE DATATYPE OF DATE COLUMN HERE

# %%
df.DATE = pd.to_datetime(df.DATE)
df.head()
# Out:
#         DATE       TAG  POSTS
# 0 2008-07-01        c#      3
# 1 2008-08-01  assembly      8
# 2 2008-08-01         c     83
# 3 2008-08-01        c#    505
# 4 2008-08-01       c++    164

# %%
# DO NOT CODE HERE
# Out:
#         DATE       TAG  POSTS
# 0 2008-07-01        c#      3
# 1 2008-08-01  assembly      8
# 2 2008-08-01         c     83
# 3 2008-08-01        c#    505
# 4 2008-08-01       c++    164

# %%
type(df.DATE[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# DO NOT CODE HERE
# check the data type
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %% [markdown]
# ## Data Manipulation
# **Chalange**:Pivot the df DataFrame so that each row is a date and each column is a programming language Store the result under a variable called reshaped_df.

# %%
reshaped_df = df.pivot(index='DATE', columns='TAG', values='POSTS')
reshaped_df
# Out:
# TAG         assembly       c      c#     c++  delphi     go    java  \
# DATE
# 2008-07-01       NaN     NaN     3.0     NaN     NaN    NaN     NaN
# 2008-08-01       8.0    83.0   505.0   164.0    14.0    NaN   222.0
# 2008-09-01      28.0   319.0  1642.0   754.0   104.0    NaN  1129.0
# 2008-10-01      16.0   302.0  1988.0   807.0   112.0    NaN  1149.0
# 2008-11-01      16.0   258.0  1730.0   734.0   141.0    NaN   956.0
# ...              ...     ...     ...     ...     ...    ...     ...
# 2022-10-01     242.0  2006.0  5801.0  3200.0   153.0  738.0  6482.0
# 2022-11-01     288.0  2186.0  6054.0  3310.0   116.0  751.0  6805.0
# 2022-12-01     284.0  1868.0  5351.0  2872.0    86.0  634.0  6004.0
# 2023-01-01     241.0  1519.0  5416.0  2692.0   114.0  740.0  5816.0
# 2023-02-01     220.0  1463.0  5371.0  2622.0   145.0  731.0  6051.0
#
# TAG         javascript   perl     php   python       r   ruby   swift
# DATE
# ...

# %% [markdown]
# **Challenge**: What are the dimensions of our new dataframe? How many rows and columns does it have? Print out the column names and print out the first 5 rows of the dataframe.

# %%
reshaped_df.shape
# Out:
# (176, 14)

# %%
# DO NOT CODE HERE
# Out:
# (176, 14)

# %%
reshaped_df.columns
# Out:
# Index(['assembly', 'c', 'c#', 'c++', 'delphi', 'go', 'java', 'javascript',
#        'perl', 'php', 'python', 'r', 'ruby', 'swift'],
#       dtype='object', name='TAG')

# %%
# DO NOT CODE HERE
# Out:
# Index(['assembly', 'c', 'c#', 'c++', 'delphi', 'go', 'java', 'javascript',
#        'perl', 'php', 'python', 'r', 'ruby', 'swift'],
#       dtype='object', name='TAG')

# %%
reshaped_df.head()
# Out:
# TAG         assembly      c      c#    c++  delphi  go    java  javascript  \
# DATE
# 2008-07-01       NaN    NaN     3.0    NaN     NaN NaN     NaN         NaN
# 2008-08-01       8.0   83.0   505.0  164.0    14.0 NaN   222.0       163.0
# 2008-09-01      28.0  319.0  1642.0  754.0   104.0 NaN  1129.0       634.0
# 2008-10-01      16.0  302.0  1988.0  807.0   112.0 NaN  1149.0       722.0
# 2008-11-01      16.0  258.0  1730.0  734.0   141.0 NaN   956.0       580.0
#
# TAG          perl    php  python    r   ruby  swift
# DATE
# 2008-07-01    NaN    NaN     NaN  NaN    NaN    NaN
# 2008-08-01   28.0  158.0   120.0  NaN   70.0    NaN
# 2008-09-01  130.0  476.0   536.0  6.0  287.0    NaN
# 2008-10-01  128.0  610.0   506.0  NaN  247.0    NaN
# 2008-11-01   97.0  500.0   450.0  1.0  158.0    NaN

# %%
# DO NOT CODE HERE
# Out:
# TAG         assembly      c      c#    c++  delphi  go    java  javascript  \
# DATE
# 2008-07-01       NaN    NaN     3.0    NaN     NaN NaN     NaN         NaN
# 2008-08-01       8.0   83.0   505.0  164.0    14.0 NaN   222.0       163.0
# 2008-09-01      28.0  319.0  1642.0  754.0   104.0 NaN  1129.0       634.0
# 2008-10-01      16.0  302.0  1988.0  807.0   112.0 NaN  1149.0       722.0
# 2008-11-01      16.0  258.0  1730.0  734.0   141.0 NaN   956.0       580.0
#
# TAG          perl    php  python    r   ruby  swift
# DATE
# 2008-07-01    NaN    NaN     NaN  NaN    NaN    NaN
# 2008-08-01   28.0  158.0   120.0  NaN   70.0    NaN
# 2008-09-01  130.0  476.0   536.0  6.0  287.0    NaN
# 2008-10-01  128.0  610.0   506.0  NaN  247.0    NaN
# 2008-11-01   97.0  500.0   450.0  1.0  158.0    NaN

# %% [markdown]
# **Challenge**: Count the number of entries per programming language. Why might the number of entries be different?

# %%
reshaped_df.count()
# Out:
# TAG
# assembly      175
# c             175
# c#            176
# c++           175
# delphi        175
# go            160
# java          175
# javascript    175
# perl          175
# php           175
# python        175
# r             173
# ruby          175
# swift         167
# dtype: int64

# %%
# DO NOT CODE HERE

# %% [markdown]
# **Chalange**:Calculate how are many NAN values are present in the dataset and replace them with "0".

# %%
reshaped_df.isna().values.sum()
# Out:
# 38

# %%
# DO NOT CODE HERE
# Out:
# 38

# %%
reshaped_df.fillna(0, inplace=True)

# %%
# DO NOT CODE HERE

# %% [markdown]
# ## Data Visualisaton with with Matplotlib

# %% [markdown]
# **Challenge**: Use the [matplotlib documentation](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot) to plot a single programming language (e.g., java) on a chart.

# %%
plt.plot(reshaped_df.index, reshaped_df.java)

# %%
# DO NOT CODE HERE

# %% [markdown]
# **Challenge**: Show two line (e.g. for Java and Python) on the same chart.

# %%
plt.xlabel('Year', fontsize=14)
plt.ylabel('Posts', fontsize=14)
plt.plot(reshaped_df.index, reshaped_df.java)
plt.plot(reshaped_df.index, reshaped_df.python)
plt.legend(fontsize=2)
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# DO NOT CODE HERE

# %% [markdown]
# **Challenge**: Use the [matplotlib documentation](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot) to plot all programming language on a chart.

# %%
plt.figure(figsize=(16,10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
for column in reshaped_df.columns:
    plt.plot(reshaped_df.index, reshaped_df[column], 
             linewidth=3, label=reshaped_df[column].name)

plt.legend(fontsize=16)

# %%
# DO NOT CODE HERE
